# %%
import pandas as pd

# %%
path = 'first_Processed_Data-Driven_Test_Case_Corrected.csv'
fdata = pd.read_csv(path)

# %%
fpath = 'first_processed_data_driven.xlsx'
fdata.to_excel(fpath, index=False)

# %%
path = 'Refined_Test_Case_Data 2.csv'
data = pd.read_csv(path)

# %%
data.head()
# Out:
#                                        testcase_name  \
# 0                                   Omnicorp Autopay
# 1                 FTC_88 Validate Credit Card Number
# 2  FTC_117 Validate Process Payment With Visa Deb...
# 3                        Non-Integrated OpenInvoices
# 4  TC_08 Validate Customer Is Able To Schedule Au...
#
#                                               prompt   testcase_type  \
# 0  Create a keyword-driven test scenario for Omni...  Keyword-Driven
# 1  Build a data-driven test plan for FTC_88 Valid...     Data-Driven
# 2  Create a data-driven test scenario for FTC_117...     Data-Driven
# 3  Generate a keyword-driven test case for Non-In...  Keyword-Driven
# 4  Generate a keyword-driven test case for TC_08 ...  Keyword-Driven
#
#                                             response  \
# 0      *** Keywords ***\n    Login To PayNOW And ...
# 1      *** Settings ***\n    Library  OperatingSy...
# 2      *** Settings ***\n    Library  OperatingSy...
# ...

# %%
xpath = 'refined_test_case_data.xlsx'

# %%
data.to_excel(xpath, sheet_name='MyData', index=False)

# %%
npath = 'aligned_data.csv'
aldf = pd.read_csv(npath)

# %%
aldf
# Out:
#   Prompt                                                                                                                                  \
# 0  Create a data-driven testcase that validates T...
# 1  Create a data-driven testcase that validates T...
# 2  Create a data-driven testcase that validates T...
# 3  Create a keyword-driven testcase that handles ...
# 4  Create a keyword-driven testcase that handles ...
# 5  Create a data-driven testcase that validates T...
# 6  Create a data-driven testcase that validates T...
# 7  Create a data-driven testcase that validates T...
# 8  Create a keyword-driven testcase that handles ...
# 9  Create a keyword-driven testcase that handles ...
#
#    Testcase Type    \
# 0  Data-driven
# 1  Data-driven
# 2  Data-driven
# 3  Keyword-driven
# 4  Keyword-driven
# 5  Data-driven
# 6  Data-driven
# 7  Data-driven
# 8  Keyword-driven
# 9  Keyword-driven
#
#   Testcase Name                                                                              \
# ...

# %%
aldf.to_excel('aligned_data.xlsx', sheet_name='MyData', index=False)
